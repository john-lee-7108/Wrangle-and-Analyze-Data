# %% [markdown]
# ## Report: act_report
# * Create a **250-word-minimum written report** called "act_report.pdf" or "act_report.html" that communicates the insights and displays the visualization(s) produced from your wrangled data. This is to be framed as an external document, like a blog post or magazine article, for example.

# %% [markdown]
# After all the gathering, assessing and cleaning part. I moved to the next step which is analysing the data we worked hard for!
# First question that came up in my mind is of course, what dog has the most favorites and retweets? I used the describe function or you can also use the max function to see what is the highest number and did a query on that tweet. With almost 130000 favorites and 80000 retweets, the labrador retriever takes the spot.

# %% [markdown]
# Next, I wondered what do people call their beloved pet. Pupper takes the cake with this one.

# %% [markdown]
# ![Screenshot%20%285%29.png](attachment:Screenshot%20%285%29.png)

# %% [markdown]
# As you can see there is no doubt that most people call their dogs puppers.

# %% [markdown]
# Another question that could be interesting for some is where do people usually tweet? Is it on their laptop? phone? Or where else. After aggregating data, I found out that most people are on their iPhones when they tweet. If you put some thoughts into it, nothing beats the comfort of receiving tweet updates on the go. Or maybe when you're laying down trying to relax. What are we going to do when we lose our phone?

# %% [markdown]
# ![Screenshot%20%287%29.png](attachment:Screenshot%20%287%29.png)

# %% [markdown]
# So what dog takes the top spot in our hearts?

# %% [markdown]
# ![Screenshot%20%2812%29.png](attachment:Screenshot%20%2812%29.png)

# %% [markdown]
# Of course it's the lovable and huggable Golden Retriever! So who is at the bottom then?

# %% [markdown]
# ![Screenshot%20%2813%29.png](attachment:Screenshot%20%2813%29.png)

# %% [markdown]
# I guess noone likes to be barked around by these terriers!

# %% [markdown]
# Last thing I also explored, is there a correlation between favorites and retweets?

# %% [markdown]
# ![Screenshot%20%2814%29.png](attachment:Screenshot%20%2814%29.png)

# %% [markdown]
# ![Screenshot%20%2815%29.png](attachment:Screenshot%20%2815%29.png)

# %% [markdown]
# According to our scatterplots and numbers, they have a strong and positive correlation. My best guess is people tend to share most things they love. I hope you gained some insights in my report.
